# %% [markdown]
# # Week 2 - Monday Lesson (variable assignment, loops, lists)

# %% [markdown]
# ## Tasks Today:
#
# 1) Int & Float assignments <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; a) Assigning int <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; b) Assigning float <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; c) Performing Calculations on ints and floats <br>
#  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; - Addition <br>
#  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; - Subtraction <br>
#  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; - Multiplication <br>
#  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; - Division <br>
#  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; - Floor Division <br>
#  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; - Modulo <br>
#  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; - Exponential <br>
# 2) String Input-Output <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; a) String Assignment <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; b) print() <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; c) String Concatenation <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; d) Type Conversion <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; e) input() <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; f) format() <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; g) Old Way (python 2) <br>
# 3) <b>In-Class Exercise #1</b> <br>
# 4) If Statements <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; a) 'is' keyword <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; b) 'in' keyword <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; c) 'not in' keyword <br>
# 5) <b>In-Class Exercise #2</b> <br>
# 6) Elif Statements <br>
# 7) Else Statements <br>
# 8) <b>In-Class Exercise #3</b> <br>
# 9) For Loops <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; a) Using 'in' keyword <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; b) Continue Statement <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; c) Break Statement <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; d) Pass Statement <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; e) Double For Loops <br>
# 10) While Loops <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; a) Looping 'While True' <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; b) While and For Loops Used Together <br>
# 11) Built-In Functions <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; a) range() <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; b) len() <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; c) help() <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; d) isinstance() <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; e) abs() <br>
# 12) Try and Except <br>
# 13) Lists <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; a) Declaring Lists <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; b) Indexing a List <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; c) .append() <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; d) .insert() <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; e) .pop() <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; f) .remove() <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; g) del() <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; h) Concatenating Two Lists <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; i) Lists Within Lists <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; j) Looping Through Lists <br>
# 14) String Manipulation <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; a) strip() <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; b) title() <br>
# 15) Working With Lists <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; a) min() <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; b) max() <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; c) sum() <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; d) sort() <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; e) Copying a List <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; f) 'in' keyword <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; g) 'not in' keyword <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; i) Checking an Empty List <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; j) Removing Instances with a Loop <br>
# 16) List Comprehensions <br>
# 17) Tuples <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; a) sorted() <br>

# %% [markdown]
# ### Int & Float Assignments

# %% [markdown]
# ##### Assigning int

# %%
number = 6
x = 7
print(x)
print(type(x))
# Out:
# 7
# <class 'int'>

# %% [markdown]
# #### Performing Calculations on ints and floats

# %% [markdown]
# ##### Addition

# %% [markdown]
# ##### Subtraction

# %%
diff = num2 - num1
print(diff)

#shorthand diff= diff - .4
print(diff)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Jay Kang\Documents\Coding Temple\Lectures\week2_day2\Tuesday_Lesson_Inclass.ipynb Cell 12' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Jay%20Kang/Documents/Coding%20Temple/Lectures/week2_day2/Tuesday_Lesson_Inclass.ipynb#ch0000011?line=0'>1</a> diff = num2 - num1
#       <a href='vscode-notebook-cell:/c%3A/Users/Jay%20Kang/Documents/Coding%20Temple/Lectures/week2_day2/Tuesday_Lesson_Inclass.ipynb#ch0000011?line=1'>2</a> print(diff)
#       <a href='vscode-notebook-cell:/c%3A/Users/Jay%20Kang/Documents/Coding%20Temple/Lectures/week2_day2/Tuesday_Lesson_Inclass.ipynb#ch0000011?line=3'>4</a> #shorthand diff= diff - .4
#
# NameError: name 'num2' is not defined

# %% [markdown]
# ##### Multiplication

# %%
# Out:
# Running cells with 'Python 3.9.13 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '"c:/Users/Jay Kang/AppData/Local/Programs/Python/Python39/python.exe" -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# ##### Division

# %%
# Out:
# Running cells with 'Python 3.9.13 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '"c:/Users/Jay Kang/AppData/Local/Programs/Python/Python39/python.exe" -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# ##### Floor Division

# %%
# Out:
# Running cells with 'Python 3.9.13 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '"c:/Users/Jay Kang/AppData/Local/Programs/Python/Python39/python.exe" -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# ##### Modulo

# %%
# Out:
# Running cells with 'Python 3.9.13 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '"c:/Users/Jay Kang/AppData/Local/Programs/Python/Python39/python.exe" -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# ##### Exponential

# %%
# Out:
# Running cells with 'Python 3.9.13 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '"c:/Users/Jay Kang/AppData/Local/Programs/Python/Python39/python.exe" -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# ### String Input-Output

# %% [markdown]
# ##### String Assignment

# %%
# Out:
# Running cells with 'Python 3.9.13 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '"c:/Users/Jay Kang/AppData/Local/Programs/Python/Python39/python.exe" -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# ##### print() <br>
# <p>Don't forget about end=' '</p>

# %%
# Out:
# Running cells with 'Python 3.9.13 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '"c:/Users/Jay Kang/AppData/Local/Programs/Python/Python39/python.exe" -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# ##### String Concatenation

# %%
# Out:
# Running cells with 'Python 3.9.13 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '"c:/Users/Jay Kang/AppData/Local/Programs/Python/Python39/python.exe" -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# ##### Type Conversion

# %%
# Out:
# Running cells with 'Python 3.9.13 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '"c:/Users/Jay Kang/AppData/Local/Programs/Python/Python39/python.exe" -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# ##### input()

# %%
# Out:
# Running cells with 'Python 3.9.13 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '"c:/Users/Jay Kang/AppData/Local/Programs/Python/Python39/python.exe" -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# ##### format()

# %%
# Out:
# Running cells with 'Python 3.9.13 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '"c:/Users/Jay Kang/AppData/Local/Programs/Python/Python39/python.exe" -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# ##### Old Way (python 2)

# %%
# Out:
# Running cells with 'Python 3.9.13 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '"c:/Users/Jay Kang/AppData/Local/Programs/Python/Python39/python.exe" -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# # In-Class Exercise 1 <br>
# <p>Create a format statement that asks for color, year, make, model and prints out the results</p>

# %%
name = input("What is your name?")
color = input("What color is your car?")
year=input("What year was your car made?")
make=input("What make is your car?")
model=input("What model is your car?")
results=f"{name}, your car is a {color} {make} {model} made in {year}" 
print(results)
# Out:
# What is your name?j
# What color is your car?blue
# What year was your car made?1090
# What make is your car?chevy
# What model is your car?impala
# j, your car is a blue chevy impala made in 1090

# %% [markdown]
# ### If Statements

# %%
# Available operators: Greater(>), Less(<),Equal(==)
# Greater or Equal(>=), Less or Equal (<=)

# Truth Tree:
# T && F = F
# T && T = T
# T || F = T
# F || T = T
# F || F = F

num1 = 5
num2 = 10
if num2 > num1:
    print("Num 2 is bigger")
# Out:
# Num 2 is bigger

# %% [markdown]
# ##### 'is' keyword

# %%
jay_grade = 99
brandt_grade = 99
print(jay_grade == brandt_grade)
print(jay_grade is brandt_grade)

#when using is, it does not make sense to use a literal - use your variables!
# Out:
# True
# True

# %% [markdown]
# ##### 'in' keyword

# %%
#check if a char is in a collection

character = "Vont" #
if "e" in character:
    print("found the e!")
elif "e" not in character:
    print("not found")
# Out:
# not found

# %% [markdown]
# ##### 'not in' keyword'

# %%
if
# Out:
# Running cells with 'Python 3.9.13 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '"c:/Users/Jay Kang/AppData/Local/Programs/Python/Python39/python.exe" -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# # In-Class Exercise 2 <br>
# <p>Ask user for input, check to see if the letter 'p' is in the input</p>

# %%
word=input("what is your name?")
result=f"{word} is awesome"
print(result)

if 'p' in word:
    print("p is found")
elif 'p' not in word:
    print("p is not found")
# Out:
# what is your name?jp
# jp is awesome
# p is found

# %% [markdown]
# ## Using 'and'/'or' with If Statements

# %%
# Out:
# Running cells with 'Python 3.9.13 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '"c:/Users/Jay Kang/AppData/Local/Programs/Python/Python39/python.exe" -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# ### Elif Statements

# %%
# Out:
# Running cells with 'Python 3.9.13 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '"c:/Users/Jay Kang/AppData/Local/Programs/Python/Python39/python.exe" -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# ### Else Statements

# %%
# see above
# Out:
# Running cells with 'Python 3.9.13 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '"c:/Users/Jay Kang/AppData/Local/Programs/Python/Python39/python.exe" -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# ### For Loops

# %%
# Out:
# Running cells with 'Python 3.9.13 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '"c:/Users/Jay Kang/AppData/Local/Programs/Python/Python39/python.exe" -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# ##### Using 'in' keyword

# %%
# see above
# Out:
# Running cells with 'Python 3.9.13 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '"c:/Users/Jay Kang/AppData/Local/Programs/Python/Python39/python.exe" -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# ##### Continue Statement

# %%
# will continue to next iteration
# Out:
# Running cells with 'Python 3.9.13 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '"c:/Users/Jay Kang/AppData/Local/Programs/Python/Python39/python.exe" -m pip install ipykernel -U --user --force-reinstall'

# %%
# Out:
# Running cells with 'Python 3.9.13 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '"c:/Users/Jay Kang/AppData/Local/Programs/Python/Python39/python.exe" -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# ##### Break Statement

# %%
# will break out of current loop
# Out:
# Running cells with 'Python 3.9.13 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '"c:/Users/Jay Kang/AppData/Local/Programs/Python/Python39/python.exe" -m pip install ipykernel -U --user --force-reinstall'

# %%
# Out:
# Running cells with 'Python 3.9.13 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '"c:/Users/Jay Kang/AppData/Local/Programs/Python/Python39/python.exe" -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# ##### Pass Statement

# %%
# mostly used as a placeholder, and will continue on same iteration
# Out:
# Running cells with 'Python 3.9.13 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '"c:/Users/Jay Kang/AppData/Local/Programs/Python/Python39/python.exe" -m pip install ipykernel -U --user --force-reinstall'

# %%
# Out:
# Running cells with 'Python 3.9.13 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '"c:/Users/Jay Kang/AppData/Local/Programs/Python/Python39/python.exe" -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# ##### Double For Loops

# %%
# Out:
# Running cells with 'Python 3.9.13 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '"c:/Users/Jay Kang/AppData/Local/Programs/Python/Python39/python.exe" -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# ### While Loops

# %%
# Out:
# Running cells with 'Python 3.9.13 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '"c:/Users/Jay Kang/AppData/Local/Programs/Python/Python39/python.exe" -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# ##### Looping 'While True'

# %%
# Out:
# Running cells with 'Python 3.9.13 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '"c:/Users/Jay Kang/AppData/Local/Programs/Python/Python39/python.exe" -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# ##### While & For Loops Used Together

# %%
# Out:
# Running cells with 'Python 3.9.13 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '"c:/Users/Jay Kang/AppData/Local/Programs/Python/Python39/python.exe" -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# ### Built-In Functions

# %% [markdown]
# ##### range()

# %%
# Out:
# Running cells with 'Python 3.9.13 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '"c:/Users/Jay Kang/AppData/Local/Programs/Python/Python39/python.exe" -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# ##### len()

# %%
# Out:
# Running cells with 'Python 3.9.13 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '"c:/Users/Jay Kang/AppData/Local/Programs/Python/Python39/python.exe" -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# ##### help()

# %%
# Out:
# Running cells with 'Python 3.9.13 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '"c:/Users/Jay Kang/AppData/Local/Programs/Python/Python39/python.exe" -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# ##### isinstance()

# %%
# Out:
# Running cells with 'Python 3.9.13 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '"c:/Users/Jay Kang/AppData/Local/Programs/Python/Python39/python.exe" -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# ##### abs()

# %%
# Out:
# Running cells with 'Python 3.9.13 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '"c:/Users/Jay Kang/AppData/Local/Programs/Python/Python39/python.exe" -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# ### Try and Except

# %%
# Out:
# Running cells with 'Python 3.9.13 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '"c:/Users/Jay Kang/AppData/Local/Programs/Python/Python39/python.exe" -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# ### Lists

# %% [markdown]
# ##### Declaring Lists

# %%
# Out:
# Running cells with 'Python 3.9.13 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '"c:/Users/Jay Kang/AppData/Local/Programs/Python/Python39/python.exe" -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# ##### Indexing a List

# %%
# Out:
# Running cells with 'Python 3.9.13 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '"c:/Users/Jay Kang/AppData/Local/Programs/Python/Python39/python.exe" -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# ##### .append()

# %%
# Out:
# Running cells with 'Python 3.9.13 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '"c:/Users/Jay Kang/AppData/Local/Programs/Python/Python39/python.exe" -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# ##### .insert()

# %%
# Out:
# Running cells with 'Python 3.9.13 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '"c:/Users/Jay Kang/AppData/Local/Programs/Python/Python39/python.exe" -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# ##### .pop()

# %%
# Out:
# Running cells with 'Python 3.9.13 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '"c:/Users/Jay Kang/AppData/Local/Programs/Python/Python39/python.exe" -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# ##### .remove()

# %%
# Out:
# Running cells with 'Python 3.9.13 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '"c:/Users/Jay Kang/AppData/Local/Programs/Python/Python39/python.exe" -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# ##### del()

# %%
# Out:
# Running cells with 'Python 3.9.13 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '"c:/Users/Jay Kang/AppData/Local/Programs/Python/Python39/python.exe" -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# ##### Concatenating Two Lists

# %%
# Out:
# Running cells with 'Python 3.9.13 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '"c:/Users/Jay Kang/AppData/Local/Programs/Python/Python39/python.exe" -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# ##### Lists Within Lists

# %%
# Out:
# Running cells with 'Python 3.9.13 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '"c:/Users/Jay Kang/AppData/Local/Programs/Python/Python39/python.exe" -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# ##### Looping Through Lists

# %%
# Out:
# Running cells with 'Python 3.9.13 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '"c:/Users/Jay Kang/AppData/Local/Programs/Python/Python39/python.exe" -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# ### String Manipulation

# %% [markdown]
# ##### .lstrip()

# %%
# string.lstrip()
# Out:
# Running cells with 'Python 3.9.13 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '"c:/Users/Jay Kang/AppData/Local/Programs/Python/Python39/python.exe" -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# ##### .rstrip()

# %%
# string.rstrip()
# Out:
# Running cells with 'Python 3.9.13 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '"c:/Users/Jay Kang/AppData/Local/Programs/Python/Python39/python.exe" -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# ##### .strip()

# %%
# string.strip()
# Out:
# Running cells with 'Python 3.9.13 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '"c:/Users/Jay Kang/AppData/Local/Programs/Python/Python39/python.exe" -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# ##### .title()

# %%
# string.title()
# Out:
# Running cells with 'Python 3.9.13 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '"c:/Users/Jay Kang/AppData/Local/Programs/Python/Python39/python.exe" -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# ### String Exercise <br>
# <p>Strip all white space and capitalize every name in the list given</p>

# %%
names = ['    coNNor', 'max', ' EVan ', 'JORDAN']
# HINT: You will need to use a for loop for iteration

# %% [markdown]
# ### Working With Lists

# %% [markdown]
# ##### min()

# %%
# min(list)

# %% [markdown]
# ##### max()

# %%
# max(list)

# %% [markdown]
# ##### sum()

# %%
# sum(list)
# Out:
# Running cells with 'Python 3.9.13 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '"c:/Users/Jay Kang/AppData/Local/Programs/Python/Python39/python.exe" -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# ##### sorted()

# %%
# sorted(list)
# Out:
# Running cells with 'Python 3.9.13 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '"c:/Users/Jay Kang/AppData/Local/Programs/Python/Python39/python.exe" -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# ##### .sort() <br>
# <p>Difference between sort and sorted, is that sorted doesn't change original list it returns a copy, while .sort changes the original list</p>

# %%
# list.sort()


# use sorted when you don't want to alter original list, use .sort() when you want to alter original list
# Out:
# Running cells with 'Python 3.9.13 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '"c:/Users/Jay Kang/AppData/Local/Programs/Python/Python39/python.exe" -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# ##### Copying a List

# %%
# [:] copies a list, doesn't alter original
# Out:
# Running cells with 'Python 3.9.13 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '"c:/Users/Jay Kang/AppData/Local/Programs/Python/Python39/python.exe" -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# ##### 'in' keyword

# %%
# Out:
# Running cells with 'Python 3.9.13 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '"c:/Users/Jay Kang/AppData/Local/Programs/Python/Python39/python.exe" -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# ##### 'not in' keyword

# %%
# Out:
# Running cells with 'Python 3.9.13 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '"c:/Users/Jay Kang/AppData/Local/Programs/Python/Python39/python.exe" -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# ##### Checking an Empty List

# %%
# if l_1: or if l_1 = []
# Out:
# Running cells with 'Python 3.9.13 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '"c:/Users/Jay Kang/AppData/Local/Programs/Python/Python39/python.exe" -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# ##### Removing Instances with a Loop

# %%
# while, remove
# Out:
# Running cells with 'Python 3.9.13 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '"c:/Users/Jay Kang/AppData/Local/Programs/Python/Python39/python.exe" -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# ### List Exercise <br>
# <p>Remove all duplicates<br><b>Extra: Create a program that will remove any duplicates from a given list</b></p>

# %%
names = ['connor', 'connor', 'bob', 'connor', 'evan', 'max', 'evan', 2, 2, 2, 3, 3, 4, 'bob', 'kevin']
# Hint 1: You will need an append
# Hint 2: Using an empty list will make life easier
# Out:
# Running cells with 'Python 3.9.13 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '"c:/Users/Jay Kang/AppData/Local/Programs/Python/Python39/python.exe" -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# ### List Comprehensions <br>
# <p>Creating a quickly generated list to work with<br>*result*  = [*transform*    *iteration*         *filter*     ]</p>

# %%
# number comprehension

# With a regular for loop


# IN a list comprehension we have a few pieces:
# The first is the counter/ variable - IN this the variable is x
# Then we have a transform for the variable 
# The finale part of a list comp is called the condition
#[variable, transform, condition]
# Out:
# Running cells with 'Python 3.9.13 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '"c:/Users/Jay Kang/AppData/Local/Programs/Python/Python39/python.exe" -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# There are a few benefits to using List comprehensions. The most obvious would be that we now have shorter code to work with instead of using 3+ lines of code in the for loop variant.
#
# Another is an added benefit to memory usage. Since the list's memory is allocated first before adding elements to it, we don't have to resize the list once we add elements to it.
#
# Lastly, list comprehensions are considered the "pythonic" way to write code by the PEP8 standards (Python Style Guide)

# %%
# square number comprehension
# Out:
# Running cells with 'Python 3.9.13 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '"c:/Users/Jay Kang/AppData/Local/Programs/Python/Python39/python.exe" -m pip install ipykernel -U --user --force-reinstall'

# %%
# string comprehension
# Out:
# Running cells with 'Python 3.9.13 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '"c:/Users/Jay Kang/AppData/Local/Programs/Python/Python39/python.exe" -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# ### Tuples <br>
# <p><b>Defined as an immutable list</b></p><br>Seperated by commas using parenthesis

# %%
# Out:
# Running cells with 'Python 3.9.13 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '"c:/Users/Jay Kang/AppData/Local/Programs/Python/Python39/python.exe" -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# ##### sorted()

# %%
# Out:
# Running cells with 'Python 3.9.13 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '"c:/Users/Jay Kang/AppData/Local/Programs/Python/Python39/python.exe" -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# ##### Adding values to a Tuple

# %%
# Out:
# Running cells with 'Python 3.9.13 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '"c:/Users/Jay Kang/AppData/Local/Programs/Python/Python39/python.exe" -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# ## Exercise #1 <br>
# <p>Cube Number Test... Print out all cubed numbers up to the total value 1000. Meaning that if the cubed number is over 1000 break the loop.</p>

# %%
# Out:
# Running cells with 'Python 3.9.13 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '"c:/Users/Jay Kang/AppData/Local/Programs/Python/Python39/python.exe" -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# ## Exercise #2 <br>
# <p>Get first prime numbers up to 100</p>

# %%
# HINT::
# An else after an if runs if the if didn’t
# An else after a for runs if the for didn’t break
# Out:
# Running cells with 'Python 3.9.13 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '"c:/Users/Jay Kang/AppData/Local/Programs/Python/Python39/python.exe" -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# ## Exercise 3 <br>
# <p>Take in a users input for their age, if they are younger than 18 print kids, if they're 18 to 65 print adults, else print seniors</p>

# %%
user=input("What is your age?")
if int(user) < 18:
    print("kids")
elif int(user) >= 18 and int(user) <= 65:
    print("adults")

# %% [markdown]
# ## Exercise 4 <br>
# <p>Given a list as a parameter,write a function that returns a list of numbers that are less than ten</b></i></p><br>
# <p> For example: Say your input parameter to the function is [1,11,14,5,8,9]...Your output should [1,5,8,9]</p>

# %%
# Use the following list - [1,11,14,5,8,9]

l_1 = [1,11,14,5,8,9]
# Out:
# Running cells with 'Python 3.9.13 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '"c:/Users/Jay Kang/AppData/Local/Programs/Python/Python39/python.exe" -m pip install ipykernel -U --user --force-reinstall'
